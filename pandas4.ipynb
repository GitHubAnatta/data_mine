# %%
import pandas as pd

# %%
data = pd.read_csv("Accidents7904.csv")
# Out:
# C:\st\Anaconda\lib\site-packages\pandas\io\parsers.py:1139: DtypeWarning: Columns (13,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
list(data)
# Out:
# ['\xef\xbb\xbfAccident_Index',
#  'Location_Easting_OSGR',
#  'Location_Northing_OSGR',
#  'Longitude',
#  'Latitude',
#  'Police_Force',
#  'Accident_Severity',
#  'Number_of_Vehicles',
#  'Number_of_Casualties',
#  'Date',
#  'Day_of_Week',
#  'Time',
#  'Local_Authority_(District)',
#  'Local_Authority_(Highway)',
#  '1st_Road_Class',
#  '1st_Road_Number',
#  'Road_Type',
#  'Speed_limit',
#  'Junction_Detail',
#  'Junction_Control',
#  '2nd_Road_Class',
#  '2nd_Road_Number',
#  'Pedestrian_Crossing-Human_Control',
#  'Pedestrian_Crossing-Physical_Facilities',
#  'Light_Conditions',
#  'Weather_Conditions',
#  'Road_Surface_Conditions',
#  'Special_Conditions_at_Site',
#  'Carriageway_Hazards',
#  'Urban_or_Rural_Area',
#  'Did_Police_Officer_Attend_Scene_of_Accident',
#  'LSOA_of_Accident_Location']

# %%
data2 = data[data.Number_of_Casualties > 10]
data2.head()
# Out:
#       ﻿Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 9191    197901CJJGC15                 290170                  915000
# 12352   197901DAVJD06                 275770                  136000
# 47712   197901LEADX69                 413790                  289000
# 51599   197903E102440                 348000                  538780
# 53716   1979040BF0740                 350320                  447620
#
#        Longitude  Latitude  Police_Force  Accident_Severity  \
# 9191         NaN       NaN             1                  2
# 12352        NaN       NaN             1                  2
# 47712        NaN       NaN             1                  2
# 51599        NaN       NaN             3                  1
# 53716        NaN       NaN             4                  3
#
#        Number_of_Vehicles  Number_of_Casualties        Date     ...      \
# 9191                    3                    12  19/03/1979     ...
# 12352                   1                    16  10/04/1979     ...
# 47712                   3                    12  14/12/1979     ...
# 51599                   2                    25  07/04/1979     ...
# 53716                   2                    11  19/06/1979     ...
#
#        Pedestrian_Crossing-Human_Control  \
# 9191                                  -1
# 12352                                 -1
# 47712                                 -1
# 51599                                  0
# 53716                                  0
#
#       Pedestrian_Crossing-Physical_Facilities  Light_Conditions  \
# 9191                                       -1                 1
# 12352                                      -1                 4
# 47712                                      -1                 4
# 51599                                       0                 6
# 53716                                       0                 1
#
#       Weather_Conditions  Road_Surface_Conditions  Special_Conditions_at_Site  \
# 9191                   8                        1                          -1
# 12352                  8                        1                          -1
# 47712                  2                        2                          -1
# 51599                  1                        2                           0
# 53716                  1                        1                           4
#
#        Carriageway_Hazards  Urban_or_Rural_Area  \
# 9191                     0                   -1
# 12352                    0                   -1
# 47712                    0                   -1
# 51599                    0                   -1
# 53716                    0                   -1
#
#        Did_Police_Officer_Attend_Scene_of_Accident  LSOA_of_Accident_Location
# 9191                                            -1                        NaN
# 12352                                           -1                        NaN
# 47712                                           -1                        NaN
# 51599                                           -1                        NaN
# 53716                                           -1                        NaN
#
# [5 rows x 32 columns]

# %%
data3 = data2[data2.Number_of_Vehicles > 20]
data3.head()
# Out:
#         ﻿Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 161828    1979420020053                 573600                  187600
# 898168    19823382N0080                 448120                  310260
# 1438603   198445BC00331                 542740                  154610
# 1644332   198534BD00087                 457440                  274200
# 1840183   198613EA11586                 409200                  418150
#
#          Longitude  Latitude  Police_Force  Accident_Severity  \
# 161828         NaN       NaN            42                  2
# 898168         NaN       NaN            33                  1
# 1438603        NaN       NaN            45                  1
# 1644332        NaN       NaN            34                  1
# 1840183        NaN       NaN            13                  2
#
#          Number_of_Vehicles  Number_of_Casualties        Date     ...      \
# 161828                   25                    20  21/01/1979     ...
# 898168                   35                    21  18/02/1982     ...
# 1438603                  26                    22  11/12/1984     ...
# 1644332                  27                    15  21/01/1985     ...
# 1840183                  51                    15  24/03/1986     ...
#
#          Pedestrian_Crossing-Human_Control  \
# 161828                                   0
# 898168                                   0
# 1438603                                  0
# 1644332                                  0
# 1840183                                  0
#
#         Pedestrian_Crossing-Physical_Facilities  Light_Conditions  \
# 161828                                        0                 6
# 898168                                        0                 1
# 1438603                                       0                 6
# 1644332                                       0                 1
# 1840183                                       0                 1
#
#         Weather_Conditions  Road_Surface_Conditions  \
# 161828                   7                        4
# 898168                   7                        2
# 1438603                  7                        2
# 1644332                  2                        2
# 1840183                  7                        2
#
#          Special_Conditions_at_Site  Carriageway_Hazards  Urban_or_Rural_Area  \
# 161828                            0                    0                   -1
# 898168                            0                    0                   -1
# 1438603                           0                    0                   -1
# 1644332                           0                    0                   -1
# 1840183                           0                    0                   -1
#
#          Did_Police_Officer_Attend_Scene_of_Accident  \
# 161828                                            -1
# 898168                                            -1
# 1438603                                           -1
# 1644332                                           -1
# 1840183                                           -1
#
#          LSOA_of_Accident_Location
# 161828                         NaN
# 898168                         NaN
# 1438603                        NaN
# 1644332                        NaN
# 1840183                        NaN
#
# [5 rows x 32 columns]

# %%
data4  = data3[(data3.Weather_Conditions == 2) | (data3.Weather_Conditions == 5)]
data4.head()
# Out:
#         ﻿Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 1644332   198534BD00087                 457440                  274200
# 2072675   1987077M10739                 364600                  390600
# 3948125   199501JO00307                 546500                  200010
# 4320578   19964100T1118                 509130                  215230
# 4815403   1998440BB0404                 467100                  151900
#
#          Longitude  Latitude  Police_Force  Accident_Severity  \
# 1644332        NaN       NaN            34                  1
# 2072675        NaN       NaN             7                  3
# 3948125        NaN       NaN             1                  2
# 4320578        NaN       NaN            41                  2
# 4815403        NaN       NaN            44                  3
#
#          Number_of_Vehicles  Number_of_Casualties        Date     ...      \
# 1644332                  27                    15  21/01/1985     ...
# 2072675                  23                    21  08/11/1987     ...
# 3948125                  22                    15  17/09/1995     ...
# 4320578                  29                    20  10/08/1996     ...
# 4815403                  32                    24  05/04/1998     ...
#
#          Pedestrian_Crossing-Human_Control  \
# 1644332                                  0
# 2072675                                  0
# 3948125                                  0
# 4320578                                  0
# 4815403                                  0
#
#         Pedestrian_Crossing-Physical_Facilities  Light_Conditions  \
# 1644332                                       0                 1
# 2072675                                       0                 4
# 3948125                                       0                 1
# 4320578                                       0                 1
# 4815403                                       0                 1
#
#         Weather_Conditions  Road_Surface_Conditions  \
# 1644332                  2                        2
# 2072675                  2                        2
# 3948125                  2                        2
# 4320578                  2                        2
# 4815403                  2                        2
#
#          Special_Conditions_at_Site  Carriageway_Hazards  Urban_or_Rural_Area  \
# 1644332                           0                    0                   -1
# 2072675                           0                    0                   -1
# 3948125                           0                    0                    2
# 4320578                           0                    0                    2
# 4815403                           0                    0                    1
#
#          Did_Police_Officer_Attend_Scene_of_Accident  \
# 1644332                                           -1
# 2072675                                           -1
# 3948125                                           -1
# 4320578                                           -1
# 4815403                                           -1
#
#          LSOA_of_Accident_Location
# 1644332                        NaN
# 2072675                        NaN
# 3948125                        NaN
# 4320578                        NaN
# 4815403                        NaN
#
# [5 rows x 32 columns]

# %%
data5 = data4[data.Light_Conditions == 5]
data5.head()
# No values
# Out:
# C:\st\Anaconda\lib\site-packages\pandas\core\frame.py:1706: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)
# Empty DataFrame
# Columns: [﻿Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Date, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Detail, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, LSOA_of_Accident_Location]
# Index: []
#
# [0 rows x 32 columns]

# %%
data5 = data4[data.Light_Conditions == 4]
data5.head()
# Out:
#         ﻿Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 2072675   1987077M10739                 364600                  390600
#
#          Longitude  Latitude  Police_Force  Accident_Severity  \
# 2072675        NaN       NaN             7                  3
#
#          Number_of_Vehicles  Number_of_Casualties        Date     ...      \
# 2072675                  23                    21  08/11/1987     ...
#
#          Pedestrian_Crossing-Human_Control  \
# 2072675                                  0
#
#         Pedestrian_Crossing-Physical_Facilities  Light_Conditions  \
# 2072675                                       0                 4
#
#         Weather_Conditions  Road_Surface_Conditions  \
# 2072675                  2                        2
#
#          Special_Conditions_at_Site  Carriageway_Hazards  Urban_or_Rural_Area  \
# 2072675                           0                    0                   -1
#
#          Did_Police_Officer_Attend_Scene_of_Accident  \
# 2072675                                           -1
#
#          LSOA_of_Accident_Location
# 2072675                        NaN
#
# [1 rows x 32 columns]

# %%
# Incidents when more than 4 people died due to snow in London
data6 = data[(data.Weather_Conditions == 3) & (data.Number_of_Casualties > 5) & (data.Police_Force == 1)]
print len(data6)
data6.head()
# Out:
# 4
#         ﻿Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 49143     197901LLTJD05                 263470                  545000
# 1025877   1983010KG0202                 548670                  185730
# 1514727   198501HD00027                 535410                  181580
# 3033694   199101TC00731                 519000                  178490
#
#          Longitude  Latitude  Police_Force  Accident_Severity  \
# 49143          NaN       NaN             1                  3
# 1025877        NaN       NaN             1                  2
# 1514727        NaN       NaN             1                  2
# 3033694        NaN       NaN             1                  2
#
#          Number_of_Vehicles  Number_of_Casualties        Date     ...      \
# 49143                     4                     8  21/12/1979     ...
# 1025877                   2                     7  02/04/1983     ...
# 1514727                   2                     7  09/02/1985     ...
# 3033694                   1                     6  31/12/1991     ...
#
#          Pedestrian_Crossing-Human_Control  \
# 49143                                   -1
# 1025877                                  0
# 1514727                                  0
# 3033694                                  0
#
#         Pedestrian_Crossing-Physical_Facilities  Light_Conditions  \
# 49143                                        -1                 4
# 1025877                                       0                 4
# 1514727                                       0                 1
# 3033694                                       0                 4
#
#         Weather_Conditions  Road_Surface_Conditions  \
# 49143                    3                        2
# 1025877                  3                        2
# 1514727                  3                        3
# 3033694                  3                        2
#
#          Special_Conditions_at_Site  Carriageway_Hazards  Urban_or_Rural_Area  \
# 49143                            -1                    0                   -1
# 1025877                           0                    0                   -1
# 1514727                           0                    0                   -1
# 3033694                           0                    0                   -1
#
#          Did_Police_Officer_Attend_Scene_of_Accident  \
# 49143                                             -1
# 1025877                                           -1
# 1514727                                           -1
# 3033694                                           -1
#
#          LSOA_of_Accident_Location
# 49143                          NaN
# 1025877                        NaN
# 1514727                        NaN
# 3033694                        NaN
#
# [4 rows x 32 columns]
